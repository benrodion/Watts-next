# %% [markdown]
# # Notebook for LSTM

# %%
#import all sorts of packages 
import numpy as np
import torch.nn as nn
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from xgboost import XGBClassifier, XGBRegressor

# %%
# load data and view
data = pd.read_csv("data/final_offshore_data_2017_2025.csv")
data.head()

#data.describe()
# Out:
#    year_mon_day  hour  wind_dir_avg_10  wind_speed_h_avg  wind_speed_avg_10  \
# 0      20170101     1       213.586816         85.714286          86.428571
# 1      20170101     2       210.905296         87.142857          90.714286
# 2      20170101     3       208.585001         89.285714          87.857143
# 3      20170101     4       209.977979         90.000000          90.000000
# 4      20170101     5       208.541568         89.285714          87.142857
#
#    air_pressure   humidity  full_datetime  capacity  volume  percentage  \
# 0      10206.75  95.714286  2017-01-01-01    873501  873501    1.014165
# 1      10199.75  96.142857  2017-01-01-02    883749  883749    1.026065
# 2      10191.50  96.000000  2017-01-01-03    872500  872500    1.013004
# 3      10182.25  96.142857  2017-01-01-04    889750  889750    1.033031
# 4      10176.25  95.571429  2017-01-01-05    893251  893251    1.037095
#
#    emission  emissionfactor   correct_days
# 0         0               0  2017-01-01-01
# 1         0               0  2017-01-01-02
# 2         0               0  2017-01-01-03
# 3         0               0  2017-01-01-04
# 4         0               0  2017-01-01-05

# %%
#separate data into X and y
X = data.drop(["volume", "capacity",  #capacity & volume are the same
                    "emission", "emissionfactor"], #are always 0 and can be ignored
                      axis=1)

# our target variable
y = data["volume"]

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Creating a Datetime-Variable for Date
# Using the code from the SARIMAX-notebook, this section creates a date-variable in YYYY-MM-DD format, imposes the `datetime`as index and limits the data to before 2025.

# %%
# Create a "date"-variable in YYYY-MM-DD format 
X["date"] = X['full_datetime'].str.rsplit('-', n=1).str[0]

X.head(1)
# Out:
#    year_mon_day  hour  wind_dir_avg_10  wind_speed_h_avg  wind_speed_avg_10  \
# 0      20170101     1       213.586816         85.714286          86.428571
#
#    air_pressure   humidity  full_datetime  percentage   correct_days  \
# 0      10206.75  95.714286  2017-01-01-01    1.014165  2017-01-01-01
#
#          date
# 0  2017-01-01

# %%
# Convert 'correct days' to datetype format for further processing
X[['date', 'hour']] = X['correct_days'].str.rsplit('-', n=1, expand=True)

X['hour'] = X['hour'].astype(int) - 1

X['datetime'] = pd.to_datetime(X['date']) + pd.to_timedelta(X['hour'], unit='H')
# Out:
# /var/folders/xk/v_s45nd9057cbzm0wb_2259m0000gn/T/ipykernel_47941/988251242.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[['date', 'hour']] = X['correct_days'].str.rsplit('-', n=1, expand=True)
# /var/folders/xk/v_s45nd9057cbzm0wb_2259m0000gn/T/ipykernel_47941/988251242.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['hour'] = X['hour'].astype(int) - 1
# /var/folders/xk/v_s45nd9057cbzm0wb_2259m0000gn/T/ipykernel_47941/988251242.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   X['datetime'] = pd.to_datetime(X['date']) + pd.to_timedelta(X['hour'], unit='H')
# /var/folders/xk/v_s45nd9057cbzm0wb_2259m0000gn/T/ipykernel_47941/988251242.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['datetime'] = pd.to_datetime(X['date']) + pd.to_timedelta(X['hour'], unit='H')

# %%
#removing data from 2025
X = X[X["date"] < "2025-01-01"]

# Set 'datetime' as index for the dataset
X.set_index('datetime', inplace=True)


X.head(3)
# Out:
#                      year_mon_day  hour  wind_dir_avg_10  wind_speed_h_avg  \
# datetime
# 2017-01-01 00:00:00      20170101     0       213.586816         85.714286
# 2017-01-01 01:00:00      20170101     1       210.905296         87.142857
# 2017-01-01 02:00:00      20170101     2       208.585001         89.285714
#
#                      wind_speed_avg_10  air_pressure   humidity  \
# datetime
# 2017-01-01 00:00:00          86.428571      10206.75  95.714286
# 2017-01-01 01:00:00          90.714286      10199.75  96.142857
# 2017-01-01 02:00:00          87.857143      10191.50  96.000000
#
#                      full_datetime  percentage   correct_days        date
# datetime
# 2017-01-01 00:00:00  2017-01-01-01    1.014165  2017-01-01-01  2017-01-01
# 2017-01-01 01:00:00  2017-01-01-02    1.026065  2017-01-01-02  2017-01-01
# 2017-01-01 02:00:00  2017-01-01-03    1.013004  2017-01-01-03  2017-01-01

# %% [markdown]
# ### Train-Test-Split
# Everything before 2024 will be used as training data, while the data for 2024 will serve as test data.

# %%
X_train = X[X["date"] < "2024-01-01"]
X_test = X[X["date"] >= "2024-01-01"]

X_train.head()
# Out:
#                      year_mon_day  hour  wind_dir_avg_10  wind_speed_h_avg  \
# datetime
# 2017-01-01 00:00:00      20170101     0       213.586816         85.714286
# 2017-01-01 01:00:00      20170101     1       210.905296         87.142857
# 2017-01-01 02:00:00      20170101     2       208.585001         89.285714
# 2017-01-01 03:00:00      20170101     3       209.977979         90.000000
# 2017-01-01 04:00:00      20170101     4       208.541568         89.285714
#
#                      wind_speed_avg_10  air_pressure   humidity  \
# datetime
# 2017-01-01 00:00:00          86.428571      10206.75  95.714286
# 2017-01-01 01:00:00          90.714286      10199.75  96.142857
# 2017-01-01 02:00:00          87.857143      10191.50  96.000000
# 2017-01-01 03:00:00          90.000000      10182.25  96.142857
# 2017-01-01 04:00:00          87.142857      10176.25  95.571429
#
#                      full_datetime  percentage   correct_days        date
# datetime
# 2017-01-01 00:00:00  2017-01-01-01    1.014165  2017-01-01-01  2017-01-01
# 2017-01-01 01:00:00  2017-01-01-02    1.026065  2017-01-01-02  2017-01-01
# 2017-01-01 02:00:00  2017-01-01-03    1.013004  2017-01-01-03  2017-01-01
# 2017-01-01 03:00:00  2017-01-01-04    1.033031  2017-01-01-04  2017-01-01
# 2017-01-01 04:00:00  2017-01-01-05    1.037095  2017-01-01-05  2017-01-01

# %% [markdown]
# ### Scaling
# For LSTM, the data needs to be scaled and normalization seems to be the way to go. However, we must be careful not to scale the temporal information.

# %%
# define temporal features - we do not scale these
time_features = ["date", "year_mon_day", "hour", "full_datetime", "correct_days" ] 

# define numeric features to be scaled
numeric_features = ["wind_dir_avg_10", "wind_speed_h_avg", "wind_speed_avg_10", "air_pressure", "humidity", "percentage"]

# Define the preprocessor
preprocessor = ColumnTransformer([
    ("date", "passthrough", time_features), # = do not scale `time_features`` 
    ("scaled_num", StandardScaler(), numeric_features)
])


# Transform the data with the scaler
X_train_norm = preprocessor.fit_transform(X_train)
X_test_norm = preprocessor.fit_transform(X_test)

# %% [markdown]
# ## Detrending/Removing Seasonality
# Ask Chris, because I am getting conflicting information.

# %% [markdown]
# ### Create 3D-Dataset
# For LSTM to work, the data needs to remodelled to be in 3D shape (see Brownlee, 2018).
