# %%
#from google.colab import drive
#drive.mount('/content/drive')
#import os
#os.chdir('/content/drive/MyDrive/ML group project')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install sktime

# %%
import pandas as pd
import numpy as np
from sktime.forecasting.compose import EnsembleForecaster
from sktime.forecasting.base import ForecastingHorizon
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.naive import NaiveForecaster
from sktime.forecasting.model_selection import ForecastingGridSearchCV
from sktime.forecasting.compose import DirectTabularRegressionForecaster
from sktime.forecasting.compose import make_reduction
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sktime.forecasting.model_selection import ForecastingGridSearchCV
from sktime.performance_metrics.forecasting import MeanSquaredError
from sktime.split import ExpandingWindowSplitter
from sktime.forecasting.compose import make_reduction
import time
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter

# %%
random_st = 41

# %%
df = pd.read_csv("data/final_offshore_data_2017_2025.csv", dtype = {'year_mon_day':'int32'})
# Removing data from 2025
df = df[df['full_datetime'] < "2025-01-01-01"]
# Restricting for the data on 2024 only
df = df[df['full_datetime'] > "2024-01-01-00"]

# Fix function
def fix_datetime_format(date_str):
    parts = date_str.split("-")
    year, month, day, hour = map(int, parts)  # Convert all parts to integers

    if hour == 24:
        hour = 0  # Reset hour to 00
        new_date = pd.Timestamp(year, month, day) + pd.Timedelta(days=1)  # Add a day
        return new_date.replace(hour=hour)  # Set hour to 00
    else:
        return pd.Timestamp(year, month, day, hour)

# Apply the fix
df["correct_days"] = df["correct_days"].apply(fix_datetime_format)
# Create a unique numerical index
#data['unique_id'] = range(1, len(data)+1)  # Ensuring uniqueness

df = df.drop(['year_mon_day', 'hour','full_datetime', 'capacity', 'emission', 'emissionfactor','percentage'], axis = 1)

print(df.tail())
print(df.shape)
# Out:
#        wind_dir_avg_10  wind_speed_h_avg  wind_speed_avg_10  air_pressure  \
# 70123       211.999178        146.000000         151.333333       10141.5
# 70124       210.666633        146.000000         148.000000       10133.5
# 70125       210.000000        146.000000         149.333333       10124.0
# 70126       213.336340        150.000000         149.333333       10118.5
# 70127       214.005693        152.666667         153.333333       10109.5
#
#         humidity   volume        correct_days
# 70123  86.571429  3718000 2024-12-31 20:00:00
# 70124  86.857143  3744500 2024-12-31 21:00:00
# 70125  88.285714  3686750 2024-12-31 22:00:00
# 70126  88.857143  3719250 2024-12-31 23:00:00
# 70127  87.428571  3453249 2025-01-01 00:00:00
# (8784, 7)

# %%
# Set datetime as index
df = df.set_index('correct_days')

# Split your data into target and exogenous variables
y = df['volume']
X = df.drop('volume', axis=1)  # All exogenous variables

# Create train/test split with test for last week of 2024
y_train, y_test, X_train, X_test = temporal_train_test_split(y, X, test_size=0.0191)

# Define the preprocessor with feature names retained
preprocessor = StandardScaler()

# Fit and transform the data
X_train_norm = preprocessor.fit_transform(X_train)
X_test_norm = preprocessor.transform(X_test)

# Convert back to DataFrame with original column names
feature_names = preprocessor.get_feature_names_out()
X_train = pd.DataFrame(X_train_norm, columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(X_test_norm, columns=X_test.columns, index=X_test.index)

# Define forecasting horizon
fh = ForecastingHorizon(np.arange(1, len(y_test) + 1))

# %%
# Initialize base forecasters
forecasters = [
    ("naive", NaiveForecaster(strategy="mean")),
    ("rf", make_reduction(RandomForestRegressor(), window_length=6)),
]

# Create ensemble
ensemble = EnsembleForecaster(forecasters=forecasters)

# %%
# With custom weights (must sum to 1)
weights = [0.5, 0.5]
weighted_ensemble = EnsembleForecaster(
    forecasters=forecasters,
    weights=weights
)

# %%
start_time = time.time()

# Fit the ensemble with exogenous variables
weighted_ensemble.fit(y_train, X=X_train)

# Generate forecasts
weighted_pred = weighted_ensemble.predict(fh, X=X_test)

# Evaluate
mape = mean_absolute_percentage_error(y_test, weighted_pred)
print(f"MAPE: {mape:.4f}")

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution Time: {execution_time:.4f} seconds")
# Out:
# MAPE: 106644945175912202240.0000
# Execution Time: 83.0754 seconds

# %%
mean_squared_error(y_test, weighted_pred)**0.5
# Out:
# 1171005.9163516557

# %%
weighted_pred
# Out:
# 2024-12-25 01:00:00    1.320157e+06
# 2024-12-25 02:00:00    1.297373e+06
# 2024-12-25 03:00:00    1.287320e+06
# 2024-12-25 04:00:00    1.286880e+06
# 2024-12-25 05:00:00    1.297888e+06
#                            ...
# 2024-12-31 20:00:00    2.207507e+06
# 2024-12-31 21:00:00    2.183640e+06
# 2024-12-31 22:00:00    2.171625e+06
# 2024-12-31 23:00:00    2.156745e+06
# 2025-01-01 00:00:00    2.150203e+06
# Freq: H, Name: volume, Length: 168, dtype: float64

# %%
# Plot the data
plt.plot(y_train.index, y_train, 'b-', label='Training Data')
plt.plot(y_test.index, y_test, 'g-', label='Test Data (Actual)')
plt.plot(weighted_pred.index, weighted_pred, 'r--', label='Predicted Values')

# Add a vertical line at the train/test split
split_date = y_train.index[-1]
plt.axvline(x=split_date, color='k', linestyle='--', label='Train/Test Split')

# Add shaded confidence interval for predictions
#if len(y_pred) > 5:
#    pred_std = y_pred.std()
#    plt.fill_between(
#        y_pred.index,
#        y_pred - 1.96 * pred_std,
#        y_pred + 1.96 * pred_std,
#        color='r', alpha=0.2, label='95% Confidence Interval'
#    )

# Customize the plot
plt.title("Time Series Forecast", fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.legend(loc='best', fontsize=10)

# Format x-axis dates
date_format = DateFormatter("%Y-%m-%d")
plt.gca().xaxis.set_major_formatter(date_format)
plt.xticks(rotation=45)

# Add grid and tight layout
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Comparison of multiple models
figsize = (15, 10)
plt.figure(figsize=figsize)

# %% [markdown]
# ***Executing the code below takes 10+ hours so we probably never use it***

# %%
cv_start_time = time.time()
# Create RF forecaster with make_reduction
rf_forecaster = make_reduction(
    RandomForestRegressor(),
    window_length=24
)

# Define parameter grid to search
param_grid = {
    "estimator__n_estimators": [100, 200],
    "estimator__max_depth": [10, 20],
    "window_length": [24]
}


# Create a proper time series CV splitter
cv_splitter = ExpandingWindowSplitter(
    initial_window=int(len(y_train) * 0.8),  # Initial training set size (80% of data)
    step_length=1,                           # Increment by 1 time step each fold
    fh=np.arange(1, 169)                      # Forecast horizon
)

# Find best forecaster with cross-validation
cv = ForecastingGridSearchCV(
    forecaster=rf_forecaster,
    param_grid=param_grid,
    cv=cv_splitter,
    strategy="refit",
    scoring=MeanSquaredError()               # Use MSE as scoring metric
)

# Fit the grid search
cv.fit(y_train, X=X_train)

# Print results
print(f"Best forecaster MSE: {cv.best_score_}")
print(f"Best parameters: {cv.best_params_}")

cv_end_time = time.time()
cv_execution_time = cv_end_time - cv_start_time
print(f"CV Execution Time: {cv_execution_time:.4f} seconds")

# %%
# Get the best forecaster from grid search
best_forecaster = cv.best_forecaster_

# For example, if predicting the next 720 time periods (month)
fh = np.arange(1, 721)
# Make predictions on test data
y_pred_grid = best_forecaster.predict(fh, X=X_test)

# %%
# Print performance metrics
mae = np.mean(np.abs(y_test - y_pred_grid))
rmse = np.sqrt(np.mean((y_test - y_pred_grid)**2))
mape = np.mean(np.abs((y_test - y_pred_grid) / y_test)) * 100

print(f"Performance Metrics:")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAPE: {mape:.4f}%")

# %%
# Sandbox!!!
# Example dictionary for multiple model predictions (replace with actual data)
predictions_dict = {
    "Model A": pd.Series(np.random.rand(20), index=y_test.index),
    "Model B": pd.Series(np.random.rand(20), index=y_test.index),
}

# Plot train and test data
plt.plot(y_train.index, y_train, 'b-', linewidth=1.5, label='Training Data')
plt.plot(y_test.index, y_test, 'g-', linewidth=2, label='Test Data (Actual)')

# Plot each model's predictions with different colors
colors = ['red', 'purple', 'orange', 'brown', 'magenta', 'cyan']
for i, (model_name, pred) in enumerate(predictions_dict.items()):
    color = colors[i % len(colors)]
    plt.plot(pred.index, pred, '--', color=color, linewidth=1.5, label=f'{model_name} Prediction')

# Add a vertical line at the train/test split
plt.axvline(x=split_date, color='k', linestyle='--', label='Train/Test Split')

# Customize the plot
plt.title("Forecasting Models Comparison", fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.legend(loc='best', fontsize=10)

# Format x-axis dates
plt.gca().xaxis.set_major_formatter(date_format)
plt.xticks(rotation=45)

# Add grid and tight layout
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Print performance metrics for each model
print("Performance Metrics:")
print("-" * 60)
print(f"{'Model':<20} {'MAE':<12} {'RMSE':<12} {'MAPE':<12}")
print("-" * 60)

for model_name, pred in predictions_dict.items():
    mae = np.mean(np.abs(y_test - pred))
    rmse = np.sqrt(np.mean((y_test - pred)**2))
    mape = np.mean(np.abs((y_test - pred) / y_test)) * 100
    print(f"{model_name:<20} {mae:<12.4f} {rmse:<12.4f} {mape:<12.4f}%")
